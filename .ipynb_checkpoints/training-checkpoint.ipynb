# %%
import random
import numpy as np
import json
import pickle
import tensorflow as tf

import nltk



from nltk.stem import WordNetLemmatizer


lemmatizer = WordNetLemmatizer()
# Out:
# WARNING:tensorflow:From C:\Users\adedi\AppData\Local\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\adedi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\adedi\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Load the initial intents data from a JSON file
intents = json.loads(open('michade_farms.json').read())

# %%
words = []
classes = []
documents = []
ignoreLetters = ['?','!','.',',']

# %%
# so for all words into words, word and intent type into documents and if intent type is not already in classes we had it.

for intent in intents['intents']:
    for pattern in intent['patterns']:
        wordlist = nltk.word_tokenize(pattern)
        words.extend(wordlist)
        documents.append((wordlist,intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
            
words = [lemmatizer.lemmatize(word) for word in words if word not in ignoreLetters]
words = sorted(set(words))

classes = sorted(set(classes)) # sort and remove duplicates

# pickling the sorted words and classes 
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# %%
# creating  bag of words to represt the document and training list
training = []
outputEmpty = [0] * len(classes)

for document in documents:
    bag = []
    wordPatterns = document[0]
    wordPatterns = [lemmatizer.lemmatize(word.lower()) for word in wordPatterns]
    for word in words: bag.append(1) if word in wordPatterns else bag.append(0)
    
    outputRow = list(outputEmpty)
    outputRow[classes.index(document[1])] = 1
    training.append(bag + outputRow)
    
random.shuffle(training)
training = np.array(training)

trainX = training[:,:len(words)]
trainY = training[:, len(words):]

# %%
# model using keras 
model = tf.keras.Sequential()

# densly connected neural network using trainX
model.add(tf.keras.layers.Dense(128, input_shape = (len(trainX[0]),),activation = 'relu'))

# dropout layer to model which randomly set 50% to 0 at each object training to reduce overfitting
model.add(tf.keras.layers.Dropout(0.5))

# densly connected neural network to add have 64 unit and activation function used in the layer
model.add(tf.keras.layers.Dense(64, activation = 'relu'))

# densly connected neural network for trainY
model.add(tf.keras.layers.Dense(len(trainY[0]), activation = 'softmax'))
# softmax ensure that the output of the layer represent probablity distrubtion or the possible classes
# Out:
# WARNING:tensorflow:From C:\Users\adedi\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# stochastic gradient descent optimizer using the following
sgd = tf.keras.optimizers.SGD(learning_rate =0.01, momentum = 0.9, nesterov =True)

# compiling the model specifying the low function as categorical cosentropy, SGD optimizer and metric to evaluate accuracy
model.compile(loss= 'categorical_crossentropy', optimizer = sgd, metrics= ['accuracy'])

# train our varaible
hist = model.fit(np.array(trainX), np.array(trainY), epochs=200, batch_size=5, verbose=1)
model.save('my_model.keras')
print('Done')
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\adedi\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\adedi\AppData\Local\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 60/60 [==============================] - 1s 2ms/step - loss: 2.7780 - accuracy: 0.0906
# Epoch 2/200
# 60/60 [==============================] - 0s 2ms/step - loss: 2.6011 - accuracy: 0.1711
# Epoch 3/200
# 60/60 [==============================] - 0s 2ms/step - loss: 2.3055 - accuracy: 0.3557
# Epoch 4/200
# 60/60 [==============================] - 0s 2ms/step - loss: 1.9652 - accuracy: 0.4329
# Epoch 5/200
# 60/60 [==============================] - 0s 2ms/step - loss: 1.6707 - accuracy: 0.5403
# Epoch 6/200
# 60/60 [==============================] - 0s 2ms/step - loss: 1.4182 - accuracy: 0.5671
# Epoch 7/200
# 60/60 [==============================] - 0s 2ms/step - loss: 1.1226 - accuracy: 0.6477
# Epoch 8/200
# 60/60 [==============================] - 0s 2ms/step - loss: 1.0187 - accuracy: 0.6779
# Epoch 9/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8306 - accuracy: 0.7383
# Epoch 10/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7796 - accuracy: 0.7181
# Epoch 11/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7436 - accuracy: 0.7685
# Epoch 12/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.8020
# Epoch 13/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.8221
# Epoch 14/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.4839 - accuracy: 0.8289
# Epoch 15/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5181 - accuracy: 0.8154
# Epoch 16/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4071 - accuracy: 0.8691
# Epoch 17/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3883 - accuracy: 0.8826
# Epoch 18/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3732 - accuracy: 0.8658
# Epoch 19/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3330 - accuracy: 0.8926
# Epoch 20/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2962 - accuracy: 0.8926
# Epoch 21/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2758 - accuracy: 0.9060
# Epoch 22/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3283 - accuracy: 0.8859
# Epoch 23/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3180 - accuracy: 0.8893
# Epoch 24/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3130 - accuracy: 0.8758
# Epoch 25/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3031 - accuracy: 0.8792
# Epoch 26/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2468 - accuracy: 0.9228
# Epoch 27/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2805 - accuracy: 0.8926
# Epoch 28/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2256 - accuracy: 0.9262
# Epoch 29/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2042 - accuracy: 0.9262
# Epoch 30/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2340 - accuracy: 0.9060
# Epoch 31/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.9295
# Epoch 32/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2208 - accuracy: 0.9094
# Epoch 33/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2165 - accuracy: 0.9161
# Epoch 34/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2463 - accuracy: 0.8960
# Epoch 35/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1986 - accuracy: 0.9128
# Epoch 36/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2279 - accuracy: 0.9094
# Epoch 37/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1960 - accuracy: 0.9161
# Epoch 38/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2064 - accuracy: 0.9329
# Epoch 39/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1937 - accuracy: 0.9094
# Epoch 40/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1782 - accuracy: 0.9329
# Epoch 41/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1470 - accuracy: 0.9396
# Epoch 42/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1872 - accuracy: 0.9329
# Epoch 43/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1587 - accuracy: 0.9362
# Epoch 44/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1805 - accuracy: 0.9228
# Epoch 45/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2120 - accuracy: 0.9128
# Epoch 46/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1551 - accuracy: 0.9430
# Epoch 47/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1692 - accuracy: 0.9195
# Epoch 48/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9430
# Epoch 49/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1512 - accuracy: 0.9329
# Epoch 50/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.9195
# Epoch 51/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1614 - accuracy: 0.9128
# Epoch 52/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1455 - accuracy: 0.9430
# Epoch 53/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1579 - accuracy: 0.9228
# Epoch 54/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1758 - accuracy: 0.9329
# Epoch 55/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1509 - accuracy: 0.9329
# Epoch 56/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1480 - accuracy: 0.9128
# Epoch 57/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.9262
# Epoch 58/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1220 - accuracy: 0.9530
# Epoch 59/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1600 - accuracy: 0.9329
# Epoch 60/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.9362
# Epoch 61/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9295
# Epoch 62/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1462 - accuracy: 0.9430
# Epoch 63/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1698 - accuracy: 0.9094
# Epoch 64/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1803 - accuracy: 0.9161
# Epoch 65/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1744 - accuracy: 0.9295
# Epoch 66/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1307 - accuracy: 0.9530
# Epoch 67/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1549 - accuracy: 0.9228
# Epoch 68/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1321 - accuracy: 0.9195
# Epoch 69/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.9295
# Epoch 70/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1489 - accuracy: 0.9228
# Epoch 71/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1486 - accuracy: 0.9228
# Epoch 72/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1394 - accuracy: 0.9228
# Epoch 73/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1382 - accuracy: 0.9295
# Epoch 74/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9262
# Epoch 75/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1249 - accuracy: 0.9329
# Epoch 76/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1217 - accuracy: 0.9362
# Epoch 77/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1171 - accuracy: 0.9463
# Epoch 78/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.9362
# Epoch 79/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1341 - accuracy: 0
200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9396
# Epoch 179/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9430
# Epoch 180/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.9295
# Epoch 181/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 0.9396
# Epoch 182/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9430
# Epoch 183/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9295
# Epoch 184/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1016 - accuracy: 0.9430
# Epoch 185/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9295
# Epoch 186/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.9262
# Epoch 187/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 0.9430
# Epoch 188/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9362
# Epoch 189/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1031 - accuracy: 0.9564
# Epoch 190/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1211 - accuracy: 0.9228
# Epoch 191/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1189 - accuracy: 0.9262
# Epoch 192/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1038 - accuracy: 0.9463
# Epoch 193/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9362
# Epoch 194/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1045 - accuracy: 0.9463
# Epoch 195/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1042 - accuracy: 0.9396
# Epoch 196/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9430
# Epoch 197/200
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 0.9396
# Epoch 198/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1060 - accuracy: 0.9362
# Epoch 199/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1037 - accuracy: 0.9463
# Epoch 200/200
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9195
# Done

# %%
# import random
# import numpy as np
# import json
# import pickle
# import tensorflow as tf
# import nltk
# from nltk.stem import WordNetLemmatizer

# lemmatizer = WordNetLemmatizer()

# nltk.download('wordnet')
# nltk.download('omw-1.4')


# # loading json file
# intents = json.loads(open('michade_farms.json').read())


# words = []
# classes = []
# documents = []
# ignoreLetters = ['?','!','.',',']

# # Collect words, classes, and documents
# for intent in intents['intents']:
#     for pattern in intent['patterns']:
#         wordlist = nltk.word_tokenize(pattern)
#         words.extend(wordlist)
#         documents.append((wordlist, intent['tag']))
#         if intent['tag'] not in classes:
#             classes.append(intent['tag'])

# # Lemmatize words and remove ignoreLetters
# words = [lemmatizer.lemmatize(word) for word in words if word not in ignoreLetters]
# words = sorted(set(words))

# classes = sorted(set(classes))  # Sort and remove duplicates

# # Pickle the sorted words and classes
# pickle.dump(words, open('words.pkl', 'wb'))
# pickle.dump(classes, open('classes.pkl', 'wb'))

# # Create bag of words to represent the document and training list
# training = []
# outputEmpty = [0] * len(classes)

# for document in documents:
#     bag = []
#     wordPatterns = document[0]
#     wordPatterns = [lemmatizer.lemmatize(word.lower()) for word in wordPatterns]
#     for word in words:
#         bag.append(1) if word in wordPatterns else bag.append(0)

#     outputRow = list(outputEmpty)
#     outputRow[classes.index(document[1])] = 1
#     training.append(bag + outputRow)

# random.shuffle(training)
# training = np.array(training)

# trainX = training[:, :len(words)]
# trainY = training[:, len(words):]

# # Model using keras
# model = tf.keras.Sequential()
# model.add(tf.keras.layers.Dense(128, input_shape=(len(trainX[0]),), activation='relu'))
# model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(64, activation='relu'))
# model.add(tf.keras.layers.Dense(len(trainY[0]), activation='softmax'))

# # Stochastic gradient descent optimizer
# sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)

# # Compile the model
# model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# # Train the model
# hist = model.fit(np.array(trainX), np.array(trainY), epochs=200, batch_size=5, verbose=1)

# # # Debugging output: Print some predictions
# # sample_questions = ["Is Michade Farms a farm?", "How are animals produced?", "Tell me about crop production."]
# # for question in sample_questions:
# #     ints = predict_class(question)
# #     print(f"Question: {question}, Predicted Intents: {ints}")

# # Save the model
# model.save('my_model.keras')
# print('Done')
